# %% [markdown]
# <a href="https://colab.research.google.com/github/A090-K/INTEL-SIP/blob/A090-K-patch-4/Task_4___Technical_Guidance_and_Coding_Environment_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import platform
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import torch

# %%
# Check Python version
print("Python Version: ", sys.version)

# Check platform details
print("Platform:", platform.platform())

# Check the current working directory
print("Current working directory:", os.getcwd())

# Check library versions
print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("TensorFlow Version:", tf.__version__)
print("Keras Version:", keras.__version__)
print("PyTorch Version:", torch.__version__)
# Out:
# Python Version:  3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# Platform: Linux-5.15.107+-x86_64-with-glibc2.31
# Current working directory: /content
# NumPy Version: 1.22.4
# Pandas Version: 1.5.3
# TensorFlow Version: 2.12.0
# Keras Version: 2.12.0
# PyTorch Version: 2.0.1+cu118

# %% [markdown]
# ![screencapture-localhost-8891-notebooks-Adarsh-environment-verification-and-familiarization-ipynb-2023-06-29-03_55_27.png](data:image/png;base64,...)
